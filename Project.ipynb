# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('/content/agri_profit_dataset.csv')

# %%
data.head(9)
# Out:
#   Record_ID        Date      Crop_Name  Variety      Market_Name  District  \
# 0    R00001  17-10-2026          Onion    Local    Trichy Market   Madurai
# 1    R00002  28-01-2025         Chilli    Local     Karur Market  Tiruppur
# 2    R00003  11-12-2025          Onion    Local  Tiruppur Market     Erode
# 3    R00004  06-10-2026  Ladies Finger   Hybrid  Dindigul Market   Madurai
# 4    R00005  09-01-2026         Potato   Hybrid   Chennai Market   Madurai
# 5    R00006  18-10-2026         Radish  Premium   Madurai Market   Chennai
# 6    R00007  21-10-2026          Beans    Local    Trichy Market     Salem
# 7    R00008  21-05-2026          Onion    Local     Erode Market     Salem
# 8    R00009  28-04-2025        Pumpkin  Premium    Trichy Market   Chennai
#
#    Quantity_Arrived_kg Demand_Level Supply_Level Weather Festival_Season  \
# 0                 1928          Low         High   Sunny             Yes
# 1                 1905       Medium         High  Cloudy             Yes
# 2                 3040       Medium         High  Cloudy             Yes
# 3                  669          Low         High   Sunny              No
# 4                 2287         High         High   Rainy             Yes
# 5                  558          Low          Low  Cloudy              No
# 6                 2120         High         High   Rainy              No
# 7                 1410         High       Medium   Rainy             Yes
# 8                 1013       Medium       Medium   Sunny              No
#
#    Transportation_Cost  Distance_to_Market_km Crop_Quality  Storage_Days  \
# 0                 3656                     13      Grade A             2
# 1                 1507                    183      Grade B            10
# 2                 3963                    142      Grade A            12
# 3                  853                    223      Grade A             3
# 4                 1601                    141      Grade C             7
# 5                 2393                     21      Grade A            10
# 6                 4988                    114      Grade C            12
# 7                 3352                    102      Grade C            14
# 8                  226                    249      Grade C             8
#
#     Buyer_Type  Farmer_Experience_Years Market_Competition  \
# 0   Wholesaler                       15               High
# 1  Supermarket                       10                Low
# 2     Retailer                       36             Medium
# 3     Exporter                       18             Medium
# 4   Wholesaler                       30             Medium
# 5   Wholesaler                       32             Medium
# 6  Supermarket                       15                Low
# 7  Supermarket                       36                Low
# 8   Wholesaler                       33                Low
#
#    Fuel_Price_per_Litre  Profit
# 0                   109   84847
# 1                   120   87738
# 2                   116   82017
# 3                   110   69649
# 4                    98   90270
# 5                   118   85635
# 6                   106   66196
# 7                   111   98321
# 8                   117   75268

# %%
data.tail(5)
# Out:
#      Record_ID        Date    Crop_Name  Variety      Market_Name  District  \
# 9995    R09996  08-01-2025  Cauliflower  Premium  Dindigul Market  Tiruppur
# 9996    R09997  18-11-2025     Beetroot    Local  Dindigul Market     Karur
# 9997    R09998  29-09-2026     Beetroot    Local     Erode Market     Karur
# 9998    R09999  22-09-2026      Brinjal  Premium    Trichy Market  Tiruppur
# 9999    R10000  05-07-2025       Potato  Premium   Madurai Market  Namakkal
#
#       Quantity_Arrived_kg Demand_Level Supply_Level Weather Festival_Season  \
# 9995                 3171         High          Low  Cloudy              No
# 9996                 3485          Low         High   Sunny              No
# 9997                 2364          Low       Medium  Cloudy             Yes
# 9998                 2911          Low       Medium   Sunny             Yes
# 9999                  525       Medium         High   Sunny             Yes
#
#       Transportation_Cost  Distance_to_Market_km Crop_Quality  Storage_Days  \
# 9995                 1103                    127      Grade C            11
# 9996                 1914                     61      Grade C             9
# 9997                 2979                     32      Grade B             0
# 9998                 2209                     75      Grade B             6
# 9999                 2071                    158      Grade C             3
#
#       Buyer_Type  Farmer_Experience_Years Market_Competition  \
# 9995    Exporter                        2             Medium
# 9996    Exporter                        8                Low
# 9997    Retailer                       40               High
# 9998  Wholesaler                       29                Low
# 9999    Exporter                       12                Low
#
#       Fuel_Price_per_Litre  Profit
# 9995                   101  109507
# 9996                   104   76652
# 9997                   108   82677
# 9998                   103  107978
# 9999                   113   85573

# %%
data.describe()
# Out:
#        Quantity_Arrived_kg  Transportation_Cost  Distance_to_Market_km  \
# count         10000.000000          10000.00000           10000.000000
# mean           2527.520300           2578.97560             128.210800
# std            1405.322467           1395.00306              70.921415
# min             100.000000            200.00000               5.000000
# 25%            1299.750000           1345.00000              67.000000
# 50%            2516.000000           2565.00000             128.000000
# 75%            3728.000000           3770.00000             190.000000
# max            5000.000000           5000.00000             250.000000
#
#        Storage_Days  Farmer_Experience_Years  Fuel_Price_per_Litre  \
# count  10000.000000             10000.000000          10000.000000
# mean       7.528200                20.409100            105.043800
# std        4.610676                11.535755              8.976132
# min        0.000000                 1.000000             90.000000
# 25%        4.000000                10.000000             97.000000
# 50%        7.000000                20.000000            105.000000
# 75%       12.000000                31.000000            113.000000
# max       15.000000                40.000000            120.000000
#
#               Profit
# count   10000.000000
# mean    92448.479900
# std     22052.766559
# min      6516.000000
# 25%     77500.000000
# 50%     92540.000000
# 75%    107625.250000
# max    171793.000000

# %%
data.shape
# Out:
# (10000, 20)

# %%
data.columns
# Out:
# Index(['Record_ID', 'Date', 'Crop_Name', 'Variety', 'Market_Name', 'District',
#        'Quantity_Arrived_kg', 'Demand_Level', 'Supply_Level', 'Weather',
#        'Festival_Season', 'Transportation_Cost', 'Distance_to_Market_km',
#        'Crop_Quality', 'Storage_Days', 'Buyer_Type', 'Farmer_Experience_Years',
#        'Market_Competition', 'Fuel_Price_per_Litre', 'Profit'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Record_ID                10000 non-null  object
#  1   Date                     10000 non-null  object
#  2   Crop_Name                10000 non-null  object
#  3   Variety                  10000 non-null  object
#  4   Market_Name              10000 non-null  object
#  5   District                 10000 non-null  object
#  6   Quantity_Arrived_kg      10000 non-null  int64
#  7   Demand_Level             10000 non-null  object
#  8   Supply_Level             10000 non-null  object
#  9   Weather                  10000 non-null  object
#  10  Festival_Season          10000 non-null  object
#  11  Transportation_Cost      10000 non-null  int64
#  12  Distance_to_Market_km    10000 non-null  int64
#  13  Crop_Quality             10000 non-null  object
#  14  Storage_Days             10000 non-null  int64
#  15  Buyer_Type               10000 non-null  object
#  16  Farmer_Experience_Years  10000 non-null  int64
#  17  Market_Competition       10000 non-null  object
#  18  Fuel_Price_per_Litre     10000 non-null  int64
#  19  Profit                   10000 non-null  int64
# dtypes: int64(7), object(13)
# memory usage: 1.5+ MB

# %%
data.isnull().sum()
# Out:
# Record_ID                  0
# Date                       0
# Crop_Name                  0
# Variety                    0
# Market_Name                0
# District                   0
# Quantity_Arrived_kg        0
# Demand_Level               0
# Supply_Level               0
# Weather                    0
# Festival_Season            0
# Transportation_Cost        0
# Distance_to_Market_km      0
# Crop_Quality               0
# Storage_Days               0
# Buyer_Type                 0
# Farmer_Experience_Years    0
# Market_Competition         0
# Fuel_Price_per_Litre       0
# Profit                     0
# dtype: int64

# %%
data.dtypes
# Out:
# Record_ID                  object
# Date                       object
# Crop_Name                  object
# Variety                    object
# Market_Name                object
# District                   object
# Quantity_Arrived_kg         int64
# Demand_Level               object
# Supply_Level               object
# Weather                    object
# Festival_Season            object
# Transportation_Cost         int64
# Distance_to_Market_km       int64
# Crop_Quality               object
# Storage_Days                int64
# Buyer_Type                 object
# Farmer_Experience_Years     int64
# Market_Competition         object
# Fuel_Price_per_Litre        int64
# Profit                      int64
# dtype: object

# %%
data.drop("Record_ID", axis=1, inplace=True)

# %%
data["Date"] = pd.to_datetime(data["Date"])
# Out:
# /tmp/ipykernel_403/2487158108.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["Date"] = pd.to_datetime(data["Date"])

# %%
data["Year"] = data["Date"].dt.year
data["Month"] = data["Date"].dt.month
data["Day"] = data["Date"].dt.day

# %%
data = data.drop("Date", axis=1)

# %%
sns.histplot(data["Profit"])
plt.show()

# %%
sns.boxplot(x="Weather", y="Profit", data=data)
plt.show()

# %%
x= data.drop(["Profit"] ,axis=1)
y = data["Profit"]

# %%
x = pd.get_dummies(x, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
dt = DecisionTreeRegressor(random_state=42)
dt.fit(x_train, y_train)
y_pred_dt = dt.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = lr.predict(x_test)
print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE : 5972.350902285654
# MSE : 47809385.35002856
# RMSE: 6914.433118486906
# R2 Score: 0.8977295795728253

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
dt = DecisionTreeRegressor(random_state=42)
dt.fit(x_train, y_train)
y_pred_dt = dt.predict(x_test)
print("Decision Tree R²:", r2_score(y_test, y_pred_dt))
# Out:
# Decision Tree R²: 0.3833331795499595

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=42)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)
R2 = r2_score(y_test, y_pred)
MAE
# Out:
# 5972.350902285654

# %%
MSE
# Out:
# 47809385.35002856

# %%
R2
# Out:
# 0.8977295795728253
